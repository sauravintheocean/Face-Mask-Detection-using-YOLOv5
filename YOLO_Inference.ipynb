# %% [markdown]
# Import Libraries

# %%
import numpy as np
import os
from pathlib import Path
from xml.dom.minidom import parse
from shutil import copyfile
# !pip install --ignore-installed PyYAML
# !pip install torch==1.7.0+cu110 torchvision==0.8.1+cu110 torchaudio===0.7.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# ...
#      |████████████████████████████████| 645kB 18.3MB/s
# ...
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |███████████████████████▌        | 834.1MB 1.3MB/s eta 0:03:51tcmalloc: large alloc 1147494400 bytes == 0x55cbaed5e000 @  0x7f3a4434b615 0x55cb762b306c 0x55cb76392eba 0x55cb762b5e8d 0x55cb763a799d 0x55cb76329fe9 0x55cb76324b0e 0x55cb762b777a 0x55cb76329e50 0x55cb76324b0e 0x55cb762b777a 0x55cb7632686a 0x55cb763a87c6 0x55cb76325ee2 0x55cb763a87c6 0x55cb76325ee2 0x55cb763a87c6 0x55cb76325ee2 0x55cb763a87c6 0x55cb7642a431 0x55cb7638b049 0x55cb762f5c84 0x55cb762b68e9 0x55cb7632aade 0x55cb762b769a 0x55cb76325a45 0x55cb76324e0d 0x55cb762b777a 0x55cb76325a45 0x55cb762b769a 0x55cb76325a45
# ...

# %%
os.chdir('/content/drive/MyDrive/cs584/Project/yolov5')

# %% [markdown]
# Detect Facemask

# %%
# !python detect.py --source ../test_img.jpeg --img-size 320 --conf 0.4 --weights runs/train/exp2/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=320, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../test_img.jpeg', update=False, view_img=False, weights=['runs/train/exp2/weights/best.pt'])
# Using torch 1.7.0+cu110 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7251912 parameters, 0 gradients
# image 1/1 /content/drive/My Drive/cs584/Project/test_img.jpeg: 256x320 5 With_Masks, 4 Without_Masks, 4 Incorrect_Masks, Done. (0.117s)
# Results saved to runs/detect/exp7
# Done. (0.759s)

# %%
from glob import glob
import matplotlib.pyplot as plt
testfiles = glob('runs/detect/exp7/*')
img = plt.imread(testfiles[0]) 
plt.imshow(img)    
plt.show
# Out:
# <function matplotlib.pyplot.show>
